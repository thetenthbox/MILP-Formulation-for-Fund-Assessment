# %% [markdown]
# # MILP/MINLP Formulation of Active Fund Manager assessment
#
# The following is a Jupyter notebook implementation of S Balan's work 'MILP and MINLP Formulation for Active fund performance analysis'

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
from gamspy import Container, Set, Parameter, Variable, Equation, Model, Sum, Sense, Options
import numpy as np
import sys
import gamspy as gp
import math
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Generating price data
#
# The following is synthetic price data, used instead of real price data to have a better intrinsic understanding of model results.

# %%
# Step 1: Define parameters
num_stocks = 50         # Total number of stocks
num_increasing = 45      # Number of stocks with increasing prices
num_decreasing = 5      # Number of stocks with decreasing prices
num_months = 6          # Number of months (time periods)
initial_price = 100      # Initial price for all stocks

np.random.seed(42)
# Ensure the total number of stocks matches the sum of increasing and decreasing stocks
assert num_increasing + num_decreasing == num_stocks, "The sum of increasing and decreasing stocks must equal the total number of stocks."

# Step 2: Generate fake price data using Brownian motion
price_array = np.zeros((num_stocks, num_months))

# Parameters for Brownian motion
volatility = 2.0  # Controls the randomness of the price movement
upward_drift = 1.5  # Drift for increasing stocks
downward_drift = -1.5  # Drift for decreasing stocks

# Generate increasing prices for the specified number of stocks
for i in range(num_increasing):
    # Simulate Brownian motion with an upward drift
    random_walk = np.cumsum(np.random.normal(0, volatility, num_months))
    price_array[i] = initial_price + np.cumsum(random_walk + upward_drift)

# Generate decreasing prices for the specified number of stocks
for i in range(num_increasing, num_increasing + num_decreasing):
    # Simulate Brownian motion with a downward drift
    random_walk = np.cumsum(np.random.normal(0, volatility, num_months))
    price_array[i] = initial_price + np.cumsum(random_walk + downward_drift)

# Ensure no negative prices (optional, depending on the simulation)
price_array = np.maximum(price_array, 0)

# Step 3: Convert the price array into a DataFrame for better visualization
tickers = [f"Stock_{i+1}" for i in range(num_stocks)]
months = [f"Month_{i+1}" for i in range(num_months)]

price_df = pd.DataFrame(price_array, index=tickers, columns=months)

# Optional: Save the fake price data to a CSV file
price_df.to_csv('fake_stock_prices_brownian.csv')

# Step 1: Calculate monthly returns for each stock
returns_array = np.zeros_like(price_array)  # Initialize an array to store returns

# Loop through each stock and calculate monthly returns
for i in range(num_stocks):
    for j in range(1, num_months):  # Start from the second month
        returns_array[i, j] = ((price_array[i, j] - price_array[i, j-1]) / price_array[i, j-1]) * 100

# Step 2: Calculate the average monthly return for each stock
average_monthly_returns = np.mean(returns_array[:, 1:], axis=1)  # Skip the first month (no return for Month 1)

# Step 3: Convert monthly returns to yearly returns
yearly_returns = average_monthly_returns * 12  # Annualize the returns

# Step 4: Calculate the average yearly return across all stocks
average_yearly_return = np.mean(yearly_returns)

# Print the result
print(f"Average Yearly Return Across All Stocks: {average_yearly_return:.2f}%")
# Out:
# Average Yearly Return Across All Stocks: 7.42%

# %%
import matplotlib.pyplot as plt

# Plotting the stock prices
plt.figure(figsize=(12, 8))  # Set the figure size

# Plot each stock's price over time
for i in range(num_stocks):
    plt.plot(months, price_array[i], label=f"Stock_{i+1}")

# Add labels and title
plt.xlabel("Months")
plt.ylabel("Price")
plt.title("Stock Prices Over Time (Brownian Motion)")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# ## Model

# %%
# Portfolio Configuration Parameters
max_exposure = 0.10  # Maximum exposure per stock
buy_exposure = 0.10  # Maximum buying limit as a fraction of NAV
max_return = 1.80  # Cap on maximum return per stock
PT = 0.50  # Portfolio turnover rate
cash_min = 0.01  # Minimum cash position as a fraction of NAV
bfee = 1.01  # Buy fee multiplier
sfee = 0.99  # Sell fee multiplier
expected_return = 1.15  # Target return for the portfolio
init_cash = 1000000  # Initial cash balance
eps = 0.0000001  # Small constant for numerical stability
M = 100000000  # Large constant for big-M method

# Define the model container
m = Container()

# Sets
time_index = num_months  # Total number of time periods
stocks = Set(container=m, name="stocks", records=tickers)  # Set of stocks
time = Set(container=m, name="time", records=np.arange(0, time_index, 1))  # Time periods
subtime = Set(container=m, domain=time, records=np.arange(1, time_index, 1))  # Excludes first period
subtime2 = Set(container=m, domain=time, records=np.arange(2, time_index, 1))  # Excludes first two periods

# Data: Stock prices indexed by stocks and time
prices = Parameter(
    container=m,
    name="prices",
    domain=[stocks, time],
    records=price_array,
)

# Variables
C = Variable(container=m, name="C", domain=time, type="Positive")  # Cash balance
V = Variable(container=m, name="V", domain=time, type="Positive")  # Net Asset Value
x = Variable(container=m, name="x", domain=[stocks, time], type="Positive")  # Holdings
x.fx[stocks, '0'] = 0  # No initial holdings

b = Variable(container=m, name="b", domain=[stocks, time], type="Positive")  # Stocks bought
bp = Variable(container=m, name="bp", domain=[stocks, time], type="SemiCont")  # Stocks bought value
sp = Variable(container=m, name="sp", domain=[stocks, time], type="Positive")  # Stocks sold value
b.fx[stocks, '0'] = 0  # No initial buying
bp.lo[stocks, time] = 20000
bp.up[stocks, time] = 100000

s = Variable(container=m, name="s", domain=[stocks, time], type="Positive")  # Stocks sold
Z = Variable(container=m, name="Z", type="free")  # Objective variable
Sr = Variable(container=m, name="Sr", domain=[stocks], type="Positive")  # Total sales
Br = Variable(container=m, name="Br", domain=[stocks], type="Positive")  # Total purchases

gamma_s = Variable(container=m, name="gs", domain=[stocks, time], type="Binary")  # Sell indicator
gamma_b = Variable(container=m, name="gb", domain=[stocks, time], type="Binary")  # Buy indicator

profit = Variable(container=m, name="profit", domain=[stocks], type="Free")  # Profit per stock
omega = Variable(container=m, name="omega", domain=[stocks], type="Binary")  # Binary variable if stock is a winner
omega_trades = Variable(container=m, name="omega_trades", domain=[stocks], type="Binary")  # Binary variable if stock was traded

# Equations
buy_or_sell = Equation(
    m,
    name="buy_or_sell",
    domain=[stocks, time],
    description="Ensures a stock is either bought or sold at time t, but not both"
)
buy_or_sell[stocks, time] = (1 >= gamma_s[stocks, time] + gamma_b[stocks, time])

omega_trades_determination = Equation(
    m,
    name="omega_trades_determination",
    domain=[stocks],
    description="Sets omega_trades to 1 if stock was traded (Br[stocks] > 0)"
)
omega_trades_determination[stocks] = (
    Sum(time, bp[stocks, time]) <= M * omega_trades[stocks]
)

omega_trades_determination2 = Equation(
    m,
    name="omega_trades_determination2",
    domain=[stocks],
    description="Ensures omega_trades is 1 if stock was traded (Br[stocks] > 0)"
)
omega_trades_determination2[stocks] = (
    Sum(time, bp[stocks, time]) >= 0.001 * omega_trades[stocks]
)

buy_limit = Equation(
    m,
    name="buy_limit",
    domain=[stocks, time],
    description="Activates gamma_b if stock is bought at time t"
)
buy_limit[stocks, time] = b[stocks, time] <= M * gamma_b[stocks, time]

sell_limit = Equation(
    m,
    name="sell_limit",
    domain=[stocks, time],
    description="Activates gamma_s if stock is sold at time t"
)
sell_limit[stocks, time] = s[stocks, time] <= M * gamma_s[stocks, time]

stocks_bought_value = Equation(
    m,
    name="stocks_bought_value",
    domain=[stocks, time],
    description="Calculates the value of stocks bought at time t"
)
stocks_bought_value[stocks, time] = (bp[stocks, time] == b[stocks, time] * prices[stocks, time])

stocks_sold_value = Equation(
    m,
    name="stocks_sold_value",
    domain=[stocks, time],
    description="Calculates the value of stocks sold at time t"
)
stocks_sold_value[stocks, time] = (sp[stocks, time] == s[stocks, time] * prices[stocks, time])

winner_determination = Equation(
    m,
    name="winner_determination",
    domain=[stocks],
    description="Sets omega to 1 if stock was a winner (profit >= 0)"
)
winner_determination[stocks] = (
    (Sr[stocks] + x[stocks, str(time_index - 1)] * prices[stocks, str(time_index - 1)]) >= 
    Br[stocks] + eps * omega[stocks] - M * (1 - omega[stocks])
)

loser_determination = Equation(
    m,
    name="loser_determination",
    domain=[stocks],
    description="Sets omega to 0 if stock was a loser (profit < 0)"
)
loser_determination[stocks] = (
    (Sr[stocks] + x[stocks, str(time_index - 1)] * prices[stocks, str(time_index - 1)]) - Br[stocks] <= 
    -eps * (1 - omega[stocks]) + M * omega[stocks])


total_sales = Equation(
    m,
    name="total_sales",
    domain=[stocks],
    description="Calculates total revenue from selling stock"
)
total_sales[stocks] = (Sr[stocks] == Sum(time, prices[stocks, time] * s[stocks, time]))

total_purchases = Equation(
    m,
    name="total_purchases",
    domain=[stocks],
    description="Calculates total cost from buying stock"
)
total_purchases[stocks] = (Br[stocks] == Sum(time, prices[stocks, time] * b[stocks, time]))

pnl = Equation(
    m,
    name="pnl",
    domain=[stocks],
    description="Calculates profit for each stock"
)
pnl[stocks] = (
    profit[stocks] == 
    (Sr[stocks] + x[stocks, str(time_index - 1)] * prices[stocks, str(time_index - 1)]) - Br[stocks]
)

portfolio_turnover = Equation(
    m,
    name="portfolio_turnover",
    description="Calculates portfolio turnover"
)
portfolio_turnover[...] = (
    PT * (V["1"] + V[str(time_index - 1)]) == 
    Sum(stocks, Sum(subtime2, b[stocks, subtime2] * prices[stocks, subtime2])) * 2
)

max_returns = Equation(
    m,
    name="max_returns",
    domain=[stocks],
    description="Caps maximum returns per stock"
)
max_returns[stocks] = (
    (Sr[stocks] + x[stocks, str(time_index - 1)] * prices[stocks, str(time_index - 1)]) <= 
    Br[stocks] * max_return
)

holdings_balance = Equation(
    m,
    name="holdings_balance",
    domain=[stocks, time],
    description="Tracks holdings balance over time"
)
holdings_balance[stocks, subtime] = (
    x[stocks, subtime] == x[stocks, subtime - 1] + b[stocks, subtime] - s[stocks, subtime]
)

holdings_balance_initial = Equation(
    m,
    name="holdings_balance_initial",
    domain=[stocks],
    description="Initial stock holdings"
)
holdings_balance_initial[stocks] = (x[stocks, "0"] == 0)

cash_balance = Equation(
    m,
    name="cash_balance",
    domain=[time],
    description="Tracks cash balance at each time period"
)
cash_balance[time] = (
    C[time] == C[time - 1] - 
    Sum(stocks, bfee * bp[stocks, time]) + 
    Sum(stocks, sfee * sp[stocks, time])
)

cash_balance_initial = Equation(
    m,
    name="cash_balance_initial",
    description="Initial cash balance"
)
cash_balance_initial[...] = (C["0"] == init_cash)

nav = Equation(
    m,
    name="nav",
    domain=[time],
    description="Calculates Net Asset Value"
)
nav[time] = (V[time] == C[time] + Sum(stocks, prices[stocks, time] * x[stocks, time]))

risk_constraint = Equation(
    m,
    name="risk_constraint",
    domain=[stocks, time],
    description="Limits position exposure"
)
risk_constraint[stocks, time] = (max_exposure * V[time] >= prices[stocks, time] * x[stocks, time])

buy_risk_constraint = Equation(
    m,
    name="buy_risk_constraint",
    domain=[stocks, time],
    description="Limits buying exposure"
)
buy_risk_constraint[stocks, time] = (buy_exposure * V[time] >= prices[stocks, time] * b[stocks, time])

Z_plus = Variable(container=m, name="Z_plus", type="Positive")
Z_minus = Variable(container=m, name="Z_minus", type="Positive")

constraint_deviation = Equation(
    container=m,
    name="constraint_deviation",
)
constraint_deviation[...] = (Sum(stocks, omega[stocks])) == Z_plus

constraint_deviation2 = Equation(
    container=m,
    name="constraint_deviation2",
)
constraint_deviation2[...] = 1 == Z_minus * (Sum(stocks, omega_trades[stocks]))

portfolio_returns = Equation(
    container=m,
    name="portfolio_returns",
)
portfolio_returns[...] = (V[str(time_index - 1)] - expected_return * init_cash == 0)

obj_function = Equation(
    container=m,
    name="obj_function",
)
obj_function[...] = (Z) == Z_plus * Z_minus

# Model definition
b1 = Model(
    container=m,
    name="b1",
    equations=m.getEquations(),
    problem="MINLP",
    sense=Sense.MIN,
    objective=Z,
)

# Solve the model
gdx_path = m.gdxOutputPath()
b1.solve(
    output=sys.stdout,
    solver='XPRESS',
    options=Options(report_solution=1),
    solver_options={
        "reslim": "30",
    }
)
# Out:
# --- Job _c84d62e3-9f03-418d-8caf-c9a05c1e53dc.gms Start 02/12/25 17:17:58 48.6.1 67fbb04b DAX-DAC arm 64bit/macOS
# --- Applying:
#     /Users/sarangbalan/miniconda3/envs/py310/lib/python3.10/site-packages/gamspy_base/gmsprmun.txt
# --- GAMS Parameters defined
#     MINLP XPRESS
#     Input /var/folders/26/q1w3l1l13l353qb4dk_p70300000gn/T/tmpfj1aavb1/_c84d62e3-9f03-418d-8caf-c9a05c1e53dc.gms
#     Output /var/folders/26/q1w3l1l13l353qb4dk_p70300000gn/T/tmpfj1aavb1/_c84d62e3-9f03-418d-8caf-c9a05c1e53dc.lst
#     ScrDir /var/folders/26/q1w3l1l13l353qb4dk_p70300000gn/T/tmpfj1aavb1/tmpecp4_oeo/
#     SysDir /Users/sarangbalan/miniconda3/envs/py310/lib/python3.10/site-packages/gamspy_base/
#     LogOption 3
#     Trace /var/folders/26/q1w3l1l13l353qb4dk_p70300000gn/T/tmpfj1aavb1/_c84d62e3-9f03-418d-8caf-c9a05c1e53dc.txt
#     License "/Users/sarangbalan/Library/Application Support/GAMSPy/gamspy_license.txt"
#     OptFile 1
#     OptDir /var/folders/26/q1w3l1l13l353qb4dk_p70300000gn/T/tmpfj1aavb1/
#     LimRow 0
#     LimCol 0
#     TraceOpt 3
#     GDX /var/folders/26/q1w3l1l13l353qb4dk_p70300000gn/T/tmpfj1aavb1/_c84d62e3-9f03-418d-8caf-c9a05c1e53dcout.gdx
#     SolPrint 1
#     PreviousWork 1
#     gdxSymbols newOrChanged
# Licensee: Sarang Balan                                   G241122+0003Ac-GEN
#           sarang.balan.20@ucl.ac.uk                               GPA102651
#           /Users/sarangbalan/Library/Application Support/GAMSPy/gamspy_license.txt
#           node:61558101 v:2
#           Time-limited license with GAMSPy usage
#           The expiration date of time-limited license is Nov 17, 2025
# Processor information: 1 socket(s), 12 core(s), and 12 thread(s) available
# --- Starting compilation
# --- _c84d62e3-9f03-418d-8caf-c9a05c1e53dc.gms(68) 4 Mb
# --- Starting execution: elapsed 0:00:00.000
# --- Generating MINLP model b1
# --- _c84d62e3-9f03-418d-8caf-c9a05c1e53dc.gms(453) 7 Mb
# ---   2,818 rows  2,365 columns  8,582 non-zeroes
# ---   60 nl-code  53 nl-non-zeroes
# ---   1,000 discrete-columns
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 1.000E-07, 1.000E+08] - Zero values observed as well
# --- Bound     [min, max] : [ 1.000E+00, 1.000E+05] - Zero values observed as well
# --- Matrix    [min, max] : [ 1.000E-03, 1.000E+08] - Zero values observed as well
# --- _c84d62e3-9f03-418d-8caf-c9a05c1e53dc.gms(453) 5 Mb
# --- Executing XPRESS (Solvelink=2): elapsed 0:00:00.004
#
# FICO-Xpress      48.6.1 67fbb04b Jan 23, 2025          DAC arm 64bit/macOS
#
# Reading parameter(s) from "/var/folders/26/q1w3l1l13l353qb4dk_p70300000gn/T/tmpfj1aavb1/xpress.opt"
# >>  reslim 30
# Finished reading from "/var/folders/26/q1w3l1l13l353qb4dk_p70300000gn/T/tmpfj1aavb1/xpress.opt"
# Xpress Optimizer 43.01
# Xpress Solver 64bit v9.4.0 Apr 16 2024
# (c) Copyright Fair Isaac Corporation 1983-2024. All rights reserved
# Licensed for use by: GAMS Development Corp. for GAMS
#
# --- GMO Q Extraction (ThreePass): 0.00s
# --- GMO setup time: 0.00s
#
# Reading Problem b1
# Problem Statistics
#         2817 (      0 spare) rows
#         2364 (      0 spare) structural columns
#         8528 (      0 spare) non-zero elements
#            2 quadratic elements in objective
#           50 quadratic elements in 1 quadratic constraints
# MIP Entity Statistics
#         1000 entities        0 sets        0 set members
# Original problem size
#    linear:    2817 rows, 2364 columns, 8528 linear coefficients
#    quadratic: 2 in obj, 1 rows, 50 in rows
# Nonlinear presolve
#    converted 1 quadratic matrix to a formula
#    converted quadratic objective into an SLP constraint
#    simplify removed 102 tokens
#    linear presolve removed 1453 rows, 1203 columns, 3244 linear coefficients
#    objective transfer row R2818 through variable C2366
#    creating 1 '+' clusters removed 47 tokens
# Presolved problem size
#    linear:    1365 rows, 1163 columns, 5285 linear coefficients
#    nonlinear: 2 coefficients, 155 tokens
#              51 mul             0 div         0 sqrt
# Problem is nonlinear presolved
# FICO Xpress v9.4.0, Hyper, solve started 17:17:58, Feb 12, 2025
# Control settings used:
# LPITERLIMIT = 2147483647
# MIPADDCUTOFF = 0
# MIPRELCUTOFF = 0
# MIPABSSTOP = 0
# MIPRELSTOP = .0001
# TIMELIMIT = 30
# LOCALSOLVER = 0
# MULTISTART_THREADS = -1
# NLPMAXTIME = 0
# XSLP_ECHOXPRSMESSAGES = 1
# NLPCALCTHREADS = -1
# NLPTHREADS = -1
# XSLP_OBJSENSE = 1
# Maximum expanded nl-formula size: 152  (row 'R2816')
# Total tokens: 155
#   12  parallel calculation threads
#   Jacobian: symbolic differentiation
#            2 base AD formula, 52.5 average complexity
#           53 in the Jacobian, 2.84906 average complexity
# Initial point integer infeasible:         1.0000
#  ------------------- Calling global solver -----------------
# FICO Xpress v9.4.0, Hyper, solve started 17:17:58, Feb 12, 2025
# Heap usage: 929KB (peak 1063KB, 1678KB system)
# Minimizing Nonconvex-MIQCP b1 using up to 12 threads and up to 24GB memory
# Original problem has:
#       1365 rows         1163 cols         5285 elements       600 entities
# Presolved problem has:
#       1365 rows         1162 cols         5084 elements       600 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 1409KB (peak 2826KB, 1678KB system)
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 5.00e-08,  1.02e+06] / [ 6.08e-03,  6.34e+04]
#   RHS and bounds [min,max] : [ 1.00e-07,  2.63e+07] / [ 1.95e-10,  8.79e+04]
#   Objective      [min,max] : [ 1.00e+00,  1.00e+00] / [ 1.00e+00,  1.00e+00]
# Autoscaling applied Curtis-Reid scaling
# Will try to keep branch and bound tree memory usage below 22.7GB
# Starting concurrent solve with dual (1 thread)
#  Concurrent-Solve,   0s
#             Dual
#     objective   sum inf
#  P   .0000000   .0000000
#
# ------- optimal --------
# Concurrent statistics:
#            Dual: 488 simplex iterations, 0.01s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    488           .000000      P      0     0        .000000     0
# Dual solved problem
#   488 simplex iterations in 0.01 seconds at time 0
# Final objective                       : 0.000000000000000e+00
#   Max primal violation      (abs/rel) : 6.250e-09 / 1.248e-13
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a            1.000000      .000000      1                     1        0      0
#    1  K      1.000000      .000000      1    370     50       1       16      0
#    2  K      1.000000      .000000      1    150    348       1       26      0
# c             .933333      .000000      2               0.933333       0      0
#    3  K       .933333      .000000      2    146    149 0.933333      29      0
#    4  K       .933333      .000000      2    123    140 0.933333      33      0
#    5  K       .933333      .000000      2    168    128 0.933333      28      0
#    6  K       .933333      .000000      2    124    171 0.933333      36      0
#    7  K       .933333      .000000      2     92    125 0.933333      28      0
#    8  K       .933333      .000000      2     59     90 0.933333      23      0
#    9  K       .933333      .000000      2     48     57 0.933333      20      0
#   10  K       .933333      .000000      2     78     48 0.933333      18      0
#   11  K       .933333      .000000      2     10     77 0.933333      14      0
#   12  K       .933333      .000000      2     25     10 0.933333      18      0
#   13  K       .933333      .000000      2     16     24 0.933333      20      0
#   14  K       .933333      .000000      2     50     15 0.933333      23      0
#   15  K       .933333      .000000      2     65     50 0.933333      24      0
#   16  K       .933333      .000000      2     31     62 0.933333      22      0
#   17  K       .933333      .000000      2     80     29 0.933333      22      0
#   18  K       .933333      .000000      2     11     78 0.933333      21      0
#   19  K       .933333      .000000      2      4     10 0.933333      22      0
#   20  K       .933333      .000000      2      2      7 0.933333      22      0
#   21  G       .933333      .000000      2      4      0 0.933333      22      0
#   22  G       .933333      .000000      2     44     46 0.933333      21      0
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 37
# Cut elements in the matrix : 1542
# Starting tree search.
# Deterministic mode with up to 12 running threads and up to 32 tasks.
# Heap usage: 6724KB (peak 7644KB, 1716KB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1      .933333      .000000      2      2      1 0.933333       8      0
#        2      .933333      .000000      2      2      3 0.933333      17      0
#        3      .933333      .000000      2      3      3 0.933333      13      0
#        4      .933333      .000000      2      4      4 0.933333      14      0
#        5      .933333      .000000      2      5      4 0.933333      14      0
#        6      .933333      .000000      2      6      4 0.933333      17      0
#        7      .933333      .000000      2      7      5 0.933333       5      0
#        8      .933333      .000000      2      8      5 0.933333      10      0
#        9      .933333      .000000      2      9      5 0.933333       4      0
#       10      .933333      .000000      2     10      4 0.933333      14      0
#       20      .933333      .000000      2     20      6 0.933333      14      0
#       30      .933333      .000000      2     28      7 0.933333      14      0
#       40      .933333      .000000      2     35      9 0.933333      10      0
#       50      .933333      .000000      2     43     10 0.933333      65      0
#       60      .933333      .000000      2     49     11 0.933333      55      0
#       70      .933333      .000000      2     57     12 0.933333      71      0
#       80      .933333      .000000      2     64     13 0.933333      75      0
#       90      .933333      .000000      2     70     13 0.933333     144      0
#      100      .933333      .000000      2     75     14 0.933333     104      0
# Elapsed time (sec): 1, estimated tree completion: 0.15684
# Heap usage: 6728KB (peak 7644KB, 10MB system)
# B&B tree size: 0.8MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      200      .933333      .000000      2    149     22 0.933333     141      1
#      301      .933333      .000000      2    203     18 0.933333      99      1
#      402      .933333      .000000      2    240     15 0.933333      30      1
#      504      .933333      .000000      2    264     24 0.933333      98      2
#      606      .933333      .000000      2    307     30 0.933333     104      2
#      706      .933333      .000000      2    355     27 0.933333     119      2
#      810      .933333      .000000      2    404     18 0.933333     127      2
#      910      .933333      .000000      2    439     20 0.933333     151      2
#     1011      .933333      .000000      2    529      9 0.933333      78      2
#     1111      .933333      .000000      2    572     20 0.933333     170      2
#     1212      .933333      .000000      2    658     32 0.933333     154      3
#     1315      .933333      .000000      2    707     29 0.933333      96      3
#     1417      .933333      .000000      2    765     18 0.933333     142      3
#     1517      .933333      .000000      2    793     23 0.933333     112      3
#     1617      .933333      .000000      2    832     32 0.933333     114      3
#     1717      .933333      .000000      2    903     27 0.933333     149      3
#     1817      .933333      .000000      2    951     28 0.933333     140      3
#     1917      .933333      .000000      2    983      1 0.933333       2      3
#     2019      .933333      .000000      2   1034     29 0.933333     108      4
#     2120      .933333      .000000      2   1094     21 0.933333      90      4
# Elapsed time (sec): 4, estimated tree completion: 0.31870
# Heap usage: 6733KB (peak 7644KB, 22MB system)
# B&B tree size: 7.0MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     2221      .933333      .000000      2   1115     32 0.933333      96      4
#     2324      .933333      .000000      2   1142     25 0.933333     110      4
#     2425      .933333      .000000      2   1169     28 0.933333     193      4
#     2525      .933333      .000000      2   1244     13 0.933333      87      4
#     2625      .933333      .000000      2   1291     29 0.933333     148      4
#     2728      .933333      .000000      2   1314     39 0.933333      99      4
#     2828      .933333      .000000      2   1369     19 0.933333     159      5
#     2928      .933333      .000000      2   1420     30 0.933333      79      5
#     3028      .933333      .000000      2   1467     28 0.933333     162      5
#     3128      .933333      .000000      2   1527     26 0.933333     107      5
#     3229      .933333      .000000      2   1548     17 0.933333      39      5
#     3329      .933333      .000000      2   1576     16 0.933333     166      5
#     3431      .933333      .000000      2   1599     30 0.933333      73      5
#     3533      .933333      .000000      2   1672     40 0.933333     100      5
#     3634      .933333      .000000      2   1705     32 0.933333      74      6
#     3736      .933333      .000000      2   1740     28 0.933333     204      6
#     3837      .933333      .000000      2   1746     34 0.933333      88      6
#     3938      .933333      .000000      2   1768     28 0.933333      87      6
#     4038      .933333      .000000      2   1766     37 0.933333      93      6
#     4139      .933333      .000000      2   1815     22 0.933333     167      6
# Elapsed time (sec): 6, estimated tree completion: 0.36129
# Heap usage: 6733KB (peak 7644KB, 22MB system)
# B&B tree size: 11MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     4239      .933333      .000000      2   1829     32 0.933333     122      6
#     4339      .933333      .000000      2   1862     32 0.933333      89      7
#     4442      .933333      .000000      2   1903     39 0.933333     104      7
#     4543      .933333      .000000      2   1922     25 0.933333     175      7
#     4646      .933333      .000000      2   1971     41 0.933333     124      7
#     4746      .933333      .000000      2   2000     27 0.933333     183      7
#     4846      .933333      .000000      2   2050     23 0.933333     118      7
#     4946      .933333      .000000      2   2115     31 0.933333      89      7
#     5046      .933333      .000000      2   2168     23 0.933333     134      7
#     5146      .933333      .000000      2   2192     20 0.933333     165      7
#     5246      .933333      .000000      2   2197     29 0.933333     121      8
#     5346      .933333      .000000      2   2215     26 0.933333     119      8
#     5446      .933333      .000000      2   2249     23 0.933333     141      8
#     5546      .933333      .000000      2   2274     18 0.933333     189      8
#     5646      .933333      .000000      2   2309     26 0.933333     102      8
#     5746      .933333      .000000      2   2351     18 0.933333     137      8
#     5846      .933333      .000000      2   2372     31 0.933333     169      8
#     5948      .933333      .000000      2   2403     32 0.933333      71      8
#     6049      .933333      .000000      2   2430     38 0.933333     123      9
#     6150      .933333      .000000      2   2462     22 0.933333      65      9
# Elapsed time (sec): 9, estimated tree completion: 0.37171
# Heap usage: 6733KB (peak 7644KB, 22MB system)
# B&B tree size: 15MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     6254      .933333      .000000      2   2465     40 0.933333     105      9
#     6355      .933333      .000000      2   2545     30 0.933333     101      9
#     6456      .933333      .000000      2   2548     29 0.933333      76      9
#     6556      .933333      .000000      2   2569     32 0.933333      94      9
#     6658      .933333      .000000      2   2600     34 0.933333     109      9
#     6758      .933333      .000000      2   2606     32 0.933333      68     10
#     6859      .933333      .000000      2   2668     36 0.933333      97     10
#     6961      .933333      .000000      2   2725     32 0.933333      72     10
#     7061      .933333      .000000      2   2744     25 0.933333     115     10
#     7161      .933333      .000000      2   2757     20 0.933333     189     10
#     7262      .933333      .000000      2   2839     17 0.933333     184     10
#     7362      .933333      .000000      2   2848     21 0.933333     153     10
#     7463      .933333      .000000      2   2907     22 0.933333     137     10
#     7563      .933333      .000000      2   2959     16 0.933333     168     11
#     7663      .933333      .000000      2   2988     28 0.933333     111     11
#     7764      .933333      .000000      2   3011     33 0.933333     142     11
#     7865      .933333      .000000      2   3036     27 0.933333      88     11
#     7965      .933333      .000000      2   3062     34 0.933333     100     11
#     8066      .933333      .000000      2   3092     32 0.933333      68     11
#     8166      .933333      .000000      2   3107     34 0.933333     110     11
# Elapsed time (sec): 12, estimated tree completion: 0.38186
# Heap usage: 6733KB (peak 7644KB, 22MB system)
# B&B tree size: 19MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     8266      .933333      .000000      2   3122     31 0.933333     115     12
#     8373      .933333      .000000      2   3140     32 0.933333     135     12
#     8474      .933333      .000000      2   3176     33 0.933333     100     12
#     8574      .933333      .000000      2   3241     19 0.933333     198     12
#     8674      .933333      .000000      2   3268     22 0.933333     110     12
#     8774      .933333      .000000      2   3296     40 0.933333      79     12
#     8874      .933333      .000000      2   3305     27 0.933333     152     12
#     8975      .933333      .000000      2   3331     12 0.933333     133     12
#     9075      .933333      .000000      2   3332     22 0.933333     160     13
#     9176      .933333      .000000      2   3338     27 0.933333      97     13
#     9277      .933333      .000000      2   3409     26 0.933333     109     13
#     9378      .933333      .000000      2   3430     24 0.933333     104     13
#     9479      .933333      .000000      2   3464     40 0.933333      92     13
#     9579      .933333      .000000      2   3493     29 0.933333      95     13
#     9680      .933333      .000000      2   3563     27 0.933333     130     13
#     9780      .933333      .000000      2   3577     35 0.933333      86     13
#     9880      .933333      .000000      2   3607     23 0.933333     151     14
#     9980      .933333      .000000      2   3713     37 0.933333     103     14
#    10084      .933333      .000000      2   3738     32 0.933333     130     14
#    11085      .933333      .000000      2   3997     25 0.933333     114     15
# Elapsed time (sec): 16, estimated tree completion: 0.40158
# Heap usage: 6733KB (peak 7644KB, 22MB system)
# B&B tree size: 27MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#    12088      .933333      .000000      2   4244     33 0.933333     111     16
#    13092      .933333      .000000      2   4580     36 0.933333     103     18
#    14092      .933333      .000000      2   4863     28 0.933333     133     19
#    15093      .933333      .000000      2   5182     22 0.933333     143     20
#    16094      .933333      .000000      2   5528     28 0.933333      96     21
#    17094      .933333      .000000      2   5814     23 0.933333     133     23
#    18094      .933333      .000000      2   6139     26 0.933333     106     24
#    19096      .933333      .000000      2   6425     36 0.933333     126     25
#    20096      .933333      .000000      2   6728     29 0.933333     120     27
#    21097      .933333      .000000      2   7085     34 0.933333     110     28
#    22098      .933333      .000000      2   7305     32 0.933333      98     29
# STOPPING - MAXTIME limit reached (TIMELIMIT=30.00  time=30.00).
# STOPPING - MAXTIME limit reached (TIMELIMIT=30.00  time=30.02).
#  *** Search unfinished ***    Time:    30.02 Nodes:      22486
# Numerical issues encountered:
#    Dual failures    :   1229 out of     99938 (ratio: 0.0123)
#    Singular bases   :     45 out of    190151 (ratio: 0.0002)
#    Predicted att. level   : 0.2137
# Heap usage: 68MB (peak 439MB, 1811KB system)
# Final MINLP objective (feas. solution)  : 9.333333333333336e-01
#   Max validation error      (abs/rel) :      .000 /      .000
#   Observed primal integral :     .191%
#   Total time :                30.025s
#   Time checks (ticks) :        382
# *** Time limit reached ***
#
# --- Fixing discrete variables not supported with XPRESS Global.
#
# --- Reading solution for model b1
# ***
# *** Solver did not provide marginals for model b1
# ***
# --- Executing after solve: elapsed 0:00:30.094
# --- _c84d62e3-9f03-418d-8caf-c9a05c1e53dc.gms(457) 5 Mb
# --- _c84d62e3-9f03-418d-8caf-c9a05c1e53dc.gms(515) 5 Mb
# --- GDX File /var/folders/26/q1w3l1l13l353qb4dk_p70300000gn/T/tmpfj1aavb1/_c84d62e3-9f03-418d-8caf-c9a05c1e53dcout.gdx
# *** Status: Normal completion
# --- Job _c84d62e3-9f03-418d-8caf-c9a05c1e53dc.gms Stop 02/12/25 17:18:28 elapsed 0:00:30.095
# [MODEL - WARNING] The solve was interrupted! Solve status: ResourceInterrupt. For further information, see https://gamspy.readthedocs.io/en/latest/reference/gamspy._model.html#gamspy.SolveStatus.
#   Solver Status Model Status          Objective Num of Equations  \
# 0      Resource      Integer  0.933333333333334             2818
#
#   Num of Variables Model Type  Solver Solver Time
# 0             2365      MINLP  XPRESS      30.035

# %%
import gamspy.utils as utils
print(utils.getAvailableSolvers())
# Out:
# ['BARON', 'CBC', 'CONOPT', 'CONOPT3', 'CONOPT4', 'CONVERT', 'COPT', 'CPLEX', 'DICOPT', 'EXAMINER', 'EXAMINER2', 'GUROBI', 'HIGHS', 'IPOPT', 'IPOPTH', 'KESTREL', 'KNITRO', 'MILES', 'MINOS', 'MOSEK', 'MPSGE', 'NLPEC', 'PATH', 'PATHNLP', 'RESHOP', 'SBB', 'SCIP', 'SHOT', 'SNOPT', 'SOPLEX', 'XPRESS']

# %%
omega.records.level.sum()
# Out:
# np.float64(17.0)

# %%
omega_trades.records.level.sum()
# Out:
# np.float64(20.0)

# %%
df = profit.records

# Filter out rows where 'level' is 0
non_zero_levels = df[df['level'] > 0]

# Find the lowest non-zero value in the 'level' column
lowest_non_zero = non_zero_levels['level'].count()

print("Lowest non-zero value in 'level':", lowest_non_zero)
# Out:
# Lowest non-zero value in 'level': 6

# %%
profit.records
# Out:
#       stocks         level  marginal  lower  upper  scale
# 0    Stock_1  8.857429e+04       NaN   -inf    inf    1.0
# 1    Stock_2  7.708398e+04       NaN   -inf    inf    1.0
# 2    Stock_3  0.000000e+00       NaN   -inf    inf    1.0
# 3    Stock_4  0.000000e+00       NaN   -inf    inf    1.0
# 4    Stock_5  0.000000e+00       NaN   -inf    inf    1.0
# 5    Stock_6  1.588939e+05       NaN   -inf    inf    1.0
# 6    Stock_7  0.000000e+00       NaN   -inf    inf    1.0
# 7    Stock_8  9.520792e+04       NaN   -inf    inf    1.0
# 8    Stock_9  8.044161e+04       NaN   -inf    inf    1.0
# 9   Stock_10  0.000000e+00       NaN   -inf    inf    1.0
# 10  Stock_11  0.000000e+00       NaN   -inf    inf    1.0
# 11  Stock_12  0.000000e+00       NaN   -inf    inf    1.0
# 12  Stock_13  0.000000e+00       NaN   -inf    inf    1.0
# 13  Stock_14  0.000000e+00       NaN   -inf    inf    1.0
# 14  Stock_15  1.600000e+04       NaN   -inf    inf    1.0
# 15  Stock_16  0.000000e+00       NaN   -inf    inf    1.0
# 16  Stock_17  0.000000e+00       NaN   -inf    inf    1.0
# 17  Stock_18  9.536823e+04       NaN   -inf    inf    1.0
# 18  Stock_19  0.000000e+00       NaN   -inf    inf    1.0
# 19  Stock_20  0.000000e+00       NaN   -inf    inf    1.0
# 20  Stock_21  0.000000e+00       NaN   -inf    inf    1.0
# 21  Stock_22  0.000000e+00       NaN   -inf    inf    1.0
# 22  Stock_23  1.600000e+04       NaN   -inf    inf    1.0
# 23  Stock_24  4.801980e+04       NaN   -inf    inf    1.0
# 24  Stock_25  0.000000e+00       NaN   -inf    inf    1.0
# 25  Stock_26 -8.003553e-11       NaN   -inf    inf    1.0
# 26  Stock_27  9.440919e+04       NaN   -inf    inf    1.0
# 27  Stock_28 -3.637979e-12       NaN   -inf    inf    1.0
# 28  Stock_29  0.000000e+00       NaN   -inf    inf    1.0
# 29  Stock_30  0.000000e+00       NaN   -inf    inf    1.0
# 30  Stock_31  0.000000e+00       NaN   -inf    inf    1.0
# 31  Stock_32  8.021553e+04       NaN   -inf    inf    1.0
# 32  Stock_33  0.000000e+00       NaN   -inf    inf    1.0
# 33  Stock_34  0.000000e+00       NaN   -inf    inf    1.0
# 34  Stock_35  0.000000e+00       NaN   -inf    inf    1.0
# 35  Stock_36  0.000000e+00       NaN   -inf    inf    1.0
# 36  Stock_37  9.520792e+04       NaN   -inf    inf    1.0
# 37  Stock_38  0.000000e+00       NaN   -inf    inf    1.0
# 38  Stock_39  7.931853e+04       NaN   -inf    inf    1.0
# 39  Stock_40  1.600000e+04       NaN   -inf    inf    1.0
# 40  Stock_41  6.397318e+02       NaN   -inf    inf    1.0
# 41  Stock_42  0.000000e+00       NaN   -inf    inf    1.0
# 42  Stock_43  0.000000e+00       NaN   -inf    inf    1.0
# 43  Stock_44  0.000000e+00       NaN   -inf    inf    1.0
# 44  Stock_45  0.000000e+00       NaN   -inf    inf    1.0
# 45  Stock_46 -1.000008e-07       NaN   -inf    inf    1.0
# 46  Stock_47  0.000000e+00       NaN   -inf    inf    1.0
# 47  Stock_48 -1.000000e-07       NaN   -inf    inf    1.0
# 48  Stock_49 -1.000008e-07       NaN   -inf    inf    1.0
# 49  Stock_50  7.920792e+04       NaN   -inf    inf    1.0

# %%
# Assuming bp.records is already a DataFrame
filtered_df = bp.records[bp.records['stocks'] == 'Stock_23']

# Display the filtered DataFrame
print(filtered_df)
# Out:
#        stocks time    level  marginal    lower  upper  scale
# 286  Stock_23    0      0.0       NaN  20000.0    inf    1.0
# 287  Stock_23    1  20000.0       NaN  20000.0    inf    1.0
# 288  Stock_23    2      0.0       NaN  20000.0    inf    1.0
# 289  Stock_23    3      0.0       NaN  20000.0    inf    1.0
# 290  Stock_23    4      0.0       NaN  20000.0    inf    1.0
# 291  Stock_23    5      0.0       NaN  20000.0    inf    1.0
# 292  Stock_23    6      0.0       NaN  20000.0    inf    1.0
# 293  Stock_23    7      0.0       NaN  20000.0    inf    1.0
# 294  Stock_23    8      0.0       NaN  20000.0    inf    1.0
# 295  Stock_23    9      0.0       NaN  20000.0    inf    1.0
# 296  Stock_23   10      0.0       NaN  20000.0    inf    1.0
# 297  Stock_23   11      0.0       NaN  20000.0    inf    1.0
# 298  Stock_23   12      0.0       NaN  20000.0    inf    1.0
